# %% [markdown]
# # Linear Algebra by Prof. Gilbert Strang—Notes from a Programmer

# %% [markdown]
# Using `numpy`, `scipy`, and `matplotlib`, this notebook exhibits the concepts taught through this course:
#
# * Gilbert Strang. 18.06 Linear Algebra. Spring 2010. Massachusetts Institute of Technology: MIT OpenCourseWare, https://ocw.mit.edu. License: Creative Commons BY-NC-SA. [Direct Link](https://ocw.mit.edu/courses/mathematics/18-06-linear-algebra-spring-2010/#)

# %% [markdown]
# ## Contents

# %% [markdown]
# 1. [**Create my chosen array**](<#Create-my-chosen-array>)
# 2. [**Basic operations**](<#Basic-operations>)
#     * [Transpose](<#Transpose>)
#         * [Matrix (2D array)](<#Matrix-(2D-array)>)
#         * [Vector (1D array)](<#Vector-(1D-array)>)
#         * [Vector (2D array)](<#Vector-(2D-array)>)
#     * [Inverse](<#Inverse>)
# 3. [**Decompositions**](<#Decompositions>)
#     * [LU](<#LU>)
#     * [QR](<#QR>)
#     * [Diagonalization (Eigendecomposition)](<#Diagonalization-(Eigendecomposition)>)
# 4. [**Subspaces**](<#Subspaces>)
#     * [Column Space C(A)](<#Column-Space-C(A)>)
#         * [Manually](<#Manually>)
#             * [QR](<#QR>)
#                 * [Orthonormal basis](<#Orthonormal-basis>)
#                 * [Independent columns](<#Independent-columns>)
#             * [LU (Independent columns)](<#LU-(Independent-columns)>)
#     * [Null Space N(A)](<#Null-Space-N(A)>)
#     * [Row Space C(At)](<#Row-Space-C(At)>)
#     * [Left Null Space N(At)](<#Left-Null-Space-N(At)>)
# 5. [**Rank-one matrix**](<#Rank-one-matrix>)
# 6. [**Least Squares**](<#Least-Squares>)
#     * [Manually](<#Manually>)
#     * [Fitting a line/parabola](<#Fitting-a-line/parabola>)
# 7. [**Properties of the determinant**](<#Properties-of-the-determinant>)
#     * [$|AB| = |A||B|$](<#$|AB|-=-|A||B|$>)
#     * [$|A^{-1}| = \frac{1}{|A|}$](<#$|A^{-1}|-=-\frac{1}{|A|}$>)
#     * [$|A^2|=|A|^2$](<#$|A^2|=|A|^2$>)
#     * [$|2A|=2^n |A|$](<#$|2A|=2^n-|A|$>)
#     * [$|A^T|=|A|$](<#$|A^T|=|A|$>)
#     * [$|U|=|A|$](<#$|U|=|A|$>)
#     * [$|Q|=1$](<#$|Q|=1$>)
# 8. [**Eigenvalues and eigenvectors**](<#Eigenvalues-and-eigenvectors>)
#     * [Product of eigenvalues](<#Product-of-eigenvalues>)
#     * [Sum of eigenvalues](<#Sum-of-eigenvalues>)
#     * [Adding to the diagonal adds to lambdas](<#Adding-to-the-diagonal-adds-to-lambdas>)
#     * [Attributes of a diagonal matrix](<#Attributes-of-a-diagonal-matrix>)
#     * [Rotation matrix often has complex lambdas](<#Rotation-matrix-often-has-complex-lambdas>)
# 9. [**Diagonalizability**](<#Diagonalizability>)
#     * [Algebraic & Geometric Multiplicity](<#Algebraic-&-Geometric-Multiplicity>)
#     * [Defective matrix](<#Defective-matrix>)
#     * [Diagonalizable matrix](<#Diagonalizable-matrix>)
#         * [Normal](<#Normal>)
#             * [Hermitian](<#Hermitian>)
#             * [Unitary](<#Unitary>)
# 10. [**Matrix Power $A^{k}$**](<#Matrix-Power-$A^{k}$>)
#     * [A diagonal matrix](<#A-diagonal-matrix>)
#     * [Any matrix](<#Any-matrix>)
# 11. [**Matrix Exponential $e^{At}$**](<#Matrix-Exponential-$e^{At}$>)
#     * [A diagonal matrix](<#A-diagonal-matrix>)
#     * [Any matrix](<#Any-matrix>)
# 12. [**Systems of difference equations**](<#Systems-of-difference-equations>)
#     * [Discrete $u_{k}=A^{k}u_{0}$](<#Discrete-$u_{k}=A^{k}u_{0}$>)
#         * [e.g. Fibonacci](<#e.g.-Fibonacci>)
#         * [Convergence](<#Convergence>)
#             * [Stability](<#Stability>)
#             * [Steady State](<#Steady-State>)
#             * [Blow Up](<#Blow-Up>)
#         * [Analyze](<#Analyze>)
#             * [Graph](<#Graph>)
#     * [Continuous $u(t)=e^{At}u(0)$](<#Continuous-$u(t)=e^{At}u(0)$>)
#         * [e.g. A 2×2 system of diff eqs](<#e.g.-A-2×2-system-of-diff-eqs>)
#         * [e.g. A 2nd order diff eq](<#e.g.-A-2nd-order-diff-eq>)
#         * [Convergence](<#Convergence>)
#             * [Stability](<#Stability>)
#             * [Steady State](<#Steady-State>)
#             * [Blow Up](<#Blow-Up>)
#         * [Analyze](<#Analyze>)
#             * [Graph](<#Graph>)
# 13. [**Markov matrix**](<#Markov-matrix>)
#     * [All entries are 0 or positive](<#All-entries-are-0-or-positive>)
#     * [All columns add to 1](<#All-columns-add-to-1>)
#     * [$\exists i: \lambda_{i} = 1$](<#$\exists-i:-\lambda_{i}-=-1$>)
#     * [$\forall j \ne i , |\lambda_{j}| \leq 1$](<#$\forall-j-\ne-i-,-|\lambda_{j}|-\leq-1$>)
#     * [It converges to a positive steady state](<#It-converges-to-a-positive-steady-state>)
#     * [$A^{k}$ is still Markov](<#$A^{k}$-is-still-Markov>)
# 14. [**Expansion with a basis**](<#Expansion-with-a-basis>)
#     * [With A](<#With-A>)
#     * [With Q (orthonormal basis)](<#With-Q-(orthonormal-basis)>)
#     * [With S (eigenvectors)](<#With-S-(eigenvectors)>)
# 15. [**Complex Vectors and Matrices**](<#Complex-Vectors-and-Matrices>)
#     * [Hermitian matrix](<#Hermitian-matrix>)
#     * [Unitary matrix](<#Unitary-matrix>)
# 16. [**Positive Definite Matrices**](<#Positive-Definite-Matrices>)

# %% [markdown]
# ## Requirements

# %%
# !pip install matplotlib==3.3.4 numpy==1.20.1 scipy==1.6.0

# %%
import numpy as np, numpy.linalg as npLA
from numpy.linalg import matrix_power
from numpy.testing import assert_allclose, assert_array_less, assert_

from scipy import linalg as LA
from scipy.linalg import inv, det, expm

import matplotlib.pyplot as plt

# %%
# Without set_, it can be used as a context manager as well.
# formatter={'float_kind':'{:_.1f}'.format}
np.set_printoptions(precision=1, suppress=True)

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Create my chosen array

# %%
def create_a_square_invertible_array():
    """Invertible (M == N)"""
    return np.array([[1, 2, 1],
                     [3, 8, 1],
                     [0, 4, 1]])


def create_a_square_singular_array():
    """Singular M == N"""
    return np.array([[1, 1, 4],
                     [2, 2, 5],
                     [3, 3, 6]])


def create_a_Hermitian_array():
    """Hermitian (M == N)"""
    return np.array([[1, 2j, 1 + 1j],
                     [-2j, 8, 4 - 3j],
                     [1 - 1j, 4 + 3j, -3]])


def create_a_unitary_array():
    """Unitary (M == N)"""
    return np.array([[.5 + .5j, .5 - .5j],
                     [.5 - .5j, .5 + .5j]])


def create_a_Markov_matrix():
    """Markov (M == N)"""
    return np.array([[.1, .01, .3],
                     [.2, .99, .3],
                     [.7, 0, .4]])


def create_a_Jordan_array():
    """Jordan (M == N)"""
    return np.array([[3, 1, 0],
                     [0, 3, 1],
                     [0, 0, 3]])


def create_a_tall_array():
    """Tall (M > N)"""
    return np.array([[1, 1],
                     [2, 2],
                     [3, 4],
                     [4, 1]])


def create_a_fat_array():
    """Fat (M < N)"""
    return np.array([[1, 2, 3, 4],
                     [1, 2, 4, 1]])


def create_a_3d_array_leading_to_stability_in_discrete_diff_eq():
    """A 3 by 3 array for a discrete differential equation that leads to stability"""
    return np.array([[0.1, 0, 0.5],
                     [0, 0.1, 0],
                     [-0.5, 0, -0.1]])


def create_a_3d_array_leading_to_steady_state_in_discrete_diff_eq():
    """A 3 by 3 array for a discrete differential equation that leads to steady state"""
    return np.array([[0.2, 0, 1],
                     [0, 0.2, 0],
                     [-1, 0, -0.1]])


def create_a_3d_array_blowing_up_in_discrete_diff_eq():
    """A 3 by 3 array for a discrete differential equation that blows up"""
    return np.array([[1, 1, 1],
                     [-1, 0.5, 0],
                     [-1, 0, -0.5]])


def create_a_3d_array_leading_to_stability_in_continuous_diff_eq():
    """A 3 by 3 array for a continuous differential equation that leads to stability"""
    return np.array([[-0.8, 1, 1],
                     [-1, -0.6, 1],
                     [-1, 1, -0.7]])


def create_a_3d_array_leading_to_steady_state_in_continuous_diff_eq():
    """A 3 by 3 array for a continuous differential equation that leads to steady state"""
    return np.array([[-0.6, 1, 1],
                     [-1, -0.5, 1],
                     [-1, 1, -0.6]])


def create_a_3d_array_blowing_up_in_continuous_diff_eq():
    """A 3 by 3 array for a continuous differential equation that blows up"""
    return np.array([[1, 1, 1],
                     [-1, 0.5, 0],
                     [-1, 0, -0.5]])


def create_a_2d_array_leading_to_stability_in_discrete_diff_eq():
    """A 2 by 2 array for a discrete differential equation that leads to stability"""
    return np.array([[0.1, 0.5],
                     [-0.5, 0.2]])


def create_a_2d_array_leading_to_steady_state_in_discrete_diff_eq():
    """A 2 by 2 array for a discrete differential equation that leads to steady state"""
    return np.array([[0.8, 0.5],
                     [-0.5, 0.9]])


def create_a_2d_array_blowing_up_in_discrete_diff_eq():
    """A 2 by 2 array for a discrete differential equation that blows up"""
    return np.array([[0.5, 1],
                     [-1, 0.8]])


def create_a_2d_array_leading_to_stability_in_continuous_diff_eq():
    """A 2 by 2 array for a continuous differential equation that leads to stability"""
    return np.array([[-0.3, 1],
                     [-1, -0.1]])


def create_a_2d_array_leading_to_steady_state_in_continuous_diff_eq():
    """A 2 by 2 array for a continuous differential equation that leads to steady state"""
    return np.array([[0, 1],
                     [-1, -0.1]])


def create_a_2d_array_blowing_up_in_continuous_diff_eq():
    """A 2 by 2 array for a continuous differential equation that blows up"""
    return np.array([[0.3, 1],
                     [-1, 0.1]])


def create_my_array():
    """The array I wish to see its attributes throughout the majority of cells.
    Feel free to change it!"""
    return create_a_square_invertible_array()


A = create_my_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Basic operations

# %% [markdown]
# ## Transpose

# %% [markdown]
# ### Matrix (2D array)

# %%
A = np.arange(1, 5).reshape((2, 2))
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
print(A.T)
# Out:
# [[1 3]
#  [2 4]]

# %% [markdown]
# ### Vector (1D array)

# %%
b = np.arange(3)
print(b)
# Out:
# [0 1 2]

# %%
print(b.T)
# Out:
# [0 1 2]

# %% [markdown]
# A 1D array is the same as its transpose.

# %% [markdown]
# 1D arrays will automatically transform to (perhaps transpose) 2D ones when they are on either side of @ functions.

# %% [markdown]
# ### Vector (2D array)

# %%
x = np.arange(3).reshape((1, 3))
print(x)
# Out:
# [[0 1 2]]

# %%
print(x.T)
# Out:
# [[0]
#  [1]
#  [2]]

# %% [markdown]
# ## Inverse

# %%
A = np.array([[1, 2],
              [3, 1]])
Ai = LA.inv(A)
print(Ai)
# Out:
# [[-0.2  0.4]
#  [ 0.6 -0.2]]

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Decompositions

# %% [markdown]
# ## LU

# %%
A = create_my_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %%
P, L, U = LA.lu(A)
print('P', P, '', 'L', L, '', 'U', U, sep='\n')
# Out:
# P
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]]
#
# L
# [[ 1.   0.   0. ]
#  [ 0.   1.   0. ]
#  [ 0.3 -0.2  1. ]]
#
# U
# [[3.  8.  1. ]
#  [0.  4.  1. ]
#  [0.  0.  0.8]]

# %% [markdown]
# ## QR

# %%
A = create_my_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %%
Q, R = LA.qr(A)
print('Q', Q, '', 'R', R, sep='\n')
# Out:
# Q
# [[-0.3  0.1  0.9]
#  [-0.9 -0.  -0.3]
#  [-0.  -1.   0.2]]
#
# R
# [[-3.2 -8.2 -1.3]
#  [ 0.  -4.  -0.9]
#  [ 0.   0.   0.8]]

# %% [markdown]
# ## Diagonalization (Eigendecomposition)

# %%
A = create_my_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %%
la, S = npLA.eig(A)
print('la', la, '', 'S', S, sep='\n')
# Out:
# la
# [9.4+0.j 0.3+1.j 0.3-1.j]
#
# S
# [[ 0.3+0.j   0. -0.5j  0. +0.5j]
#  [ 0.9+0.j  -0.1+0.2j -0.1-0.2j]
#  [ 0.4+0.j   0.8+0.j   0.8-0.j ]]

# %%
print(np.diagflat(la))
# Out:
# [[9.4+0.j 0. +0.j 0. +0.j]
#  [0. +0.j 0.3+1.j 0. +0.j]
#  [0. +0.j 0. +0.j 0.3-1.j]]

# %%
print(S @ np.diagflat(la) @ inv(S))
# Out:
# [[1.-0.j 2.+0.j 1.+0.j]
#  [3.-0.j 8.-0.j 1.+0.j]
#  [0.-0.j 4.-0.j 1.+0.j]]

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Subspaces

# %%
A = create_my_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %% [markdown]
# ## Column Space C(A)

# %% [markdown]
# (Using SVD, Orthonormal basis)

# %%
col_sp_A_orthonormal_basis_by_SVD = LA.orth(A)
print(col_sp_A_orthonormal_basis_by_SVD)
# Out:
# [[-0.2  0.1  1. ]
#  [-0.9  0.4 -0.3]
#  [-0.4 -0.9 -0. ]]

# %% [markdown]
# ### Manually

# %% [markdown]
# #### QR

# %% [markdown]
# ##### Orthonormal basis

# %%
Q, R, P = LA.qr(A, pivoting=True)
rank_A = npLA.matrix_rank(A)
print('Q', Q, '', 'R', R, '', 'P', P, '', 'rank', rank_A, sep='\n')
# Out:
# Q
# [[-0.2 -0.3 -0.9]
#  [-0.9 -0.4  0.3]
#  [-0.4  0.9 -0.2]]
#
# R
# [[-9.2 -2.8 -1.5]
#  [ 0.  -1.4  0.2]
#  [ 0.   0.  -0.8]]
#
# P
# [1 0 2]
#
# rank
# 3

# %%
col_sp_A_orthonormal_basis_by_QR = Q[:, :rank_A]
print(col_sp_A_orthonormal_basis_by_QR)
# Out:
# [[-0.2 -0.3 -0.9]
#  [-0.9 -0.4  0.3]
#  [-0.4  0.9 -0.2]]

# %% [markdown]
# ##### Independent columns

# %%
Q, R = LA.qr(A)
print('Q', Q, '', 'R', R, '', 'rank', rank_A, sep='\n')
# Out:
# Q
# [[-0.3  0.1  0.9]
#  [-0.9 -0.  -0.3]
#  [-0.  -1.   0.2]]
#
# R
# [[-3.2 -8.2 -1.3]
#  [ 0.  -4.  -0.9]
#  [ 0.   0.   0.8]]
#
# rank
# 3

# %%
def obtain_unique_indices_of_first_nonzero_col_in_each_row(U_resulted_by_decomposition: np.ndarray) -> list:
    # I should first convert all the "-0." to "0." so that nonzero() can find them.
    U_copy = U_resulted_by_decomposition.copy()
    U_copy[abs(U_copy) < 1.e-7] = 0

    # Because some rows in U may not have even one nonzero element,
    # I have to find the index for the first one in two steps.
    index_of_all_nonzero_cols_in_each_row = (
        [U_copy[i, :].nonzero()[0] for i in range(U_copy.shape[0])]
    )

    index_of_first_nonzero_col_in_each_row = (
        [indices[0] for indices in index_of_all_nonzero_cols_in_each_row
         if len(indices) > 0]
    )

    # Because two rows or more may have the same indices for their first nonzero element,
    # I should remove duplicates.
    unique_indices = sorted(list(set(index_of_first_nonzero_col_in_each_row)))
    return unique_indices

# %%
index_of_linearly_independent_cols_of_A = obtain_unique_indices_of_first_nonzero_col_in_each_row(R)

col_sp_A_independent_columns_by_QR = A[:, index_of_linearly_independent_cols_of_A]

print(col_sp_A_independent_columns_by_QR)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %% [markdown]
# We can create them by Q and R too:

# %%
col_sp_A_independent_columns_by_QR = Q @ R[:, index_of_linearly_independent_cols_of_A]

print(col_sp_A_independent_columns_by_QR)
# Out:
# [[1. 2. 1.]
#  [3. 8. 1.]
#  [0. 4. 1.]]

# %% [markdown]
# #### LU (Independent columns)

# %%
P, L, U = LA.lu(A)
print('P', P, '', 'L', L, '', 'U', U, sep='\n')
# Out:
# P
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]]
#
# L
# [[ 1.   0.   0. ]
#  [ 0.   1.   0. ]
#  [ 0.3 -0.2  1. ]]
#
# U
# [[3.  8.  1. ]
#  [0.  4.  1. ]
#  [0.  0.  0.8]]

# %%
index_of_linearly_independent_cols_of_A = obtain_unique_indices_of_first_nonzero_col_in_each_row(U)

col_sp_A_independent_columns_by_LU = A[:, index_of_linearly_independent_cols_of_A]

print(col_sp_A_independent_columns_by_LU)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %% [markdown]
# We can create them by P, L, and U too:

# %%
col_sp_A_independent_columns_by_LU = P @ L @ U[:, index_of_linearly_independent_cols_of_A]

print(col_sp_A_independent_columns_by_LU)
# Out:
# [[1. 2. 1.]
#  [3. 8. 1.]
#  [0. 4. 1.]]

# %% [markdown]
# ## Null Space N(A)

# %% [markdown]
# (Using SVD, Orthonormal basis)

# %%
null_sp_A = LA.null_space(A)
print(null_sp_A)
# Out:
# []

# %%
LA.norm(null_sp_A)
# Out:
# 0.0

# %% [markdown]
# ## Row Space C(At)

# %%
row_sp_A = LA.orth(A.T)
print(row_sp_A)
# Out:
# [[-0.3  0.9  0.3]
#  [-0.9 -0.2 -0.2]
#  [-0.2 -0.3  0.9]]

# %% [markdown]
# ## Left Null Space N(At)

# %%
left_null_sp_A = LA.null_space(A.T)
print(left_null_sp_A)
# Out:
# []

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Rank-one matrix

# %%
u = np.array([[1],
              [2],
              [3]])

v = np.array([[1],
              [4],
              [5]])

A = u @ v.T

print(A)
# Out:
# [[ 1  4  5]
#  [ 2  8 10]
#  [ 3 12 15]]

# %%
npLA.matrix_rank(A)
# Out:
# 1

# %% [markdown]
# Why is computing determinant and eigenvalues for rank-one matrices **easy**?

# %% [markdown]
# All eigenvalues of a rank-one matrix are _zeros_ except one of them, which happens when `u` is not orthogonal to `v` (i.e. when `A` is diagonalizable) and is given by a simple dot product:

# %%
print(u.T @ v)
# Out:
# [[24]]

# %%
print(LA.eigvals(A))
# Out:
# [24.+0.j -0.+0.j  0.+0.j]

# %% [markdown]
# Because rank-one matrices are _singular_, their determinant is simply _zero_.

# %%
LA.det(A)
# Out:
# 0.0

# %% [markdown]
# If I write a matrix as a sum of only rank-one matrices, how can it help with computing eigenvalues for the original matrix?

# %% [markdown]
# See the good answers for this question on _math.stackexchange.com_: [Eigenvalues of a sum of rank-one matrices?](https://math.stackexchange.com/q/112186/890001)

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Least Squares

# %%
A = np.column_stack([np.ones(3), np.arange(1, 4)]).astype('int')
b = np.array([1, 2, 2])
print('A', A, '', 'b', b, sep='\n')
# Out:
# A
# [[1 1]
#  [1 2]
#  [1 3]]
#
# b
# [1 2 2]

# %%
x_hat, *_ = LA.lstsq(A, b)
print(x_hat)
# Out:
# [0.7 0.5]

# %% [markdown]
# The power of `lstsq()` is that it does not need N(A) == 0.

# %% [markdown]
# ## Manually

# %% [markdown]
# In this manual approach, all columns of A should be linearly independent.

# %%
At_A = A.T @ A
At_b = A.T @ b
print('At_A', At_A, '', 'At_b', At_b, sep='\n')
# Out:
# At_A
# [[ 3  6]
#  [ 6 14]]
#
# At_b
# [ 5 11]

# %%
x_hat = inv(At_A) @ At_b
print(x_hat)
# Out:
# [0.7 0.5]

# %% [markdown]
# Or:

# %%
x_hat = LA.solve(At_A, At_b)
print(x_hat)
# Out:
# [0.7 0.5]

# %% [markdown]
# ## Fitting a line/parabola

# %%
pt_x = np.array([1., 2.5, 3.5, 4., 5., 7., 8.5])
pt_y = np.array([0.3, 1.1, 1.5, 2.0, 3.2, 6.6, 8.6])

line_A = np.column_stack([pt_x, np.ones(len(pt_x))])
line_x_hat, line_residues, *_ = LA.lstsq(line_A, pt_y)
line_a, line_b = line_x_hat

parabola_A = np.column_stack([pt_x ** 2, pt_x, np.ones(len(pt_x))])
parabola_x_hat, parabola_residues, *_ = LA.lstsq(parabola_A, pt_y)
parabola_a, parabola_b, parabola_c = parabola_x_hat

print('Residues')
print('line:\t', line_residues, sep='\t')
print('parabola:', parabola_residues, sep='\t')
# Out:
# Residues
# line:		3.1152232142857175
# parabola:	0.3954624919193907

# %%
plt.plot(pt_x, pt_y, 'o', label='Original data')

input_x = np.arange(0, 9, .1)
plt.plot(input_x, line_a * input_x + line_b, label='Fitted line')
plt.plot(input_x, parabola_a * input_x ** 2 + parabola_b * input_x + parabola_c, label='Fitted parabola')
plt.grid(alpha=0.25)
plt.legend()

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Properties of the determinant

# %%
A, B = [np.random.rand(3, 3) for _ in range(2)]

# %% [markdown]
# ## $|AB| = |A||B|$

# %%
assert_allclose(
    det(A @ B),
    det(A) * det(B)
)

# %% [markdown]
# ## $|A^{-1}| = \frac{1}{|A|}$

# %%
assert_allclose(
    det(inv(A)),
    1 / det(A)
)

# %% [markdown]
# ## $|A^2|=|A|^2$

# %%
assert_allclose(
    det(matrix_power(A, 2)),
    det(A) ** 2
)

# %% [markdown]
# ## $|2A|=2^n |A|$

# %%
assert_allclose(
    det(2 * A),
    2 ** A.shape[0] * det(A)
)

# %% [markdown]
# ## $|A^T|=|A|$

# %%
assert_allclose(
    det(A.T),
    det(A)
)

# %% [markdown]
# ## $|U|=|A|$

# %%
*_, U = LA.lu(A)
assert_allclose(
    abs(det(U)),
    abs(det(A)),
)

# %% [markdown]
# ## $|Q|=1$

# %%
Q_a_unitary_matrix = LA.orth(A)
assert_allclose(
    abs(det(Q_a_unitary_matrix)),
    1,
    atol=0.1
)

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Eigenvalues and eigenvectors

# %%
A = create_my_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %%
la, S = npLA.eig(A)
print('la', la, '', 'S', S, sep='\n')
# Out:
# la
# [9.4+0.j 0.3+1.j 0.3-1.j]
#
# S
# [[ 0.3+0.j   0. -0.5j  0. +0.5j]
#  [ 0.9+0.j  -0.1+0.2j -0.1-0.2j]
#  [ 0.4+0.j   0.8+0.j   0.8-0.j ]]

# %% [markdown]
# ## Product of eigenvalues

# %%
from functools import reduce
from operator import mul

product_of_eigenvalues = reduce(mul, la)
assert_allclose(
    product_of_eigenvalues,
    det(A)
)

# %% [markdown]
# ## Sum of eigenvalues

# %%
A.trace()
# Out:
# 10

# %%
sum_of_eigenvalues = la.sum()
assert_allclose(
    sum_of_eigenvalues,
    A.trace()
)

# %% [markdown]
# ## Adding to the diagonal adds to lambdas

# %%
assert_allclose(
    LA.eigvals(A + 100 * np.identity(3)),
    la + 100
)

# %% [markdown]
# ## Attributes of a diagonal matrix

# %%
D = np.diagflat(np.arange(1, 4))
print(D)
# Out:
# [[1 0 0]
#  [0 2 0]
#  [0 0 3]]

# %%
la, S = LA.eig(D)
print('la', la, '', 'S', S, sep='\n')
# Out:
# la
# [1.+0.j 2.+0.j 3.+0.j]
#
# S
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
def test_in_a_diagonal_matrix_eigenvalues_are_the_ones_on_the_diagonal():
    assert_allclose(
        np.diag(D),
        la
    )


test_in_a_diagonal_matrix_eigenvalues_are_the_ones_on_the_diagonal()

# %%
def test_in_a_diagonal_matrix_eigenvectors_form_the_identity():
    assert_allclose(
        S,
        np.identity(D.shape[0])
    )


test_in_a_diagonal_matrix_eigenvectors_form_the_identity()

# %% [markdown]
# ## Rotation matrix often has complex lambdas

# %%
from numpy import sin, cos


def generate_2_by_2_rotation_matrix(theta):
    return np.array([[cos(theta), -sin(theta)],
                     [sin(theta), cos(theta)]])


R_90 = generate_2_by_2_rotation_matrix(np.pi / 2)
print(R_90)
# Out:
# [[ 0. -1.]
#  [ 1.  0.]]

# %%
def test_R_90_is_antisymmetric():
    assert_allclose(
        -R_90.T,
        R_90,
        atol=1e-7
    )


test_R_90_is_antisymmetric()

# %%
la = LA.eigvals(R_90)
print(la)
# Out:
# [0.+1.j 0.-1.j]

# %%
def test_R_90_has_pure_imaginary_lambdas():
    assert_allclose(
        la.real,
        np.zeros_like(la.real),
        atol=1e-7
    )


test_R_90_has_pure_imaginary_lambdas()

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Diagonalizability

# %% [markdown]
# ## Algebraic & Geometric Multiplicity

# %%
A = create_my_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %% [markdown]
# I've used the `eig()` by `numpy.linalg` because it doesn't show _zero_ imaginary parts.

# %%
la, S = npLA.eig(A)
print('la', la, '', 'S', S, sep='\n')
# Out:
# la
# [9.4+0.j 0.3+1.j 0.3-1.j]
#
# S
# [[ 0.3+0.j   0. -0.5j  0. +0.5j]
#  [ 0.9+0.j  -0.1+0.2j -0.1-0.2j]
#  [ 0.4+0.j   0.8+0.j   0.8-0.j ]]

# %%
from collections import Counter


def compute_algebraic_multiplicities(M: np.ndarray) -> dict:
    return Counter(npLA.eigvals(M))


def compute_geometric_multiplicities(M: np.ndarray) -> dict:
    geo_multiplicities = {}

    for l in npLA.eigvals(M):
        A_minus_lambda_I = M - l * np.identity(M.shape[0])
        eigenspace = LA.null_space(A_minus_lambda_I)
        dim_of_eigenspace = eigenspace.shape[1]

        geo_multiplicities[l] = dim_of_eigenspace

    return geo_multiplicities


def print_alg_and_geo_multiplicities(M: np.ndarray):
    alg_ms = compute_algebraic_multiplicities(M)
    geo_ms = compute_geometric_multiplicities(M)

    print('lambda  ', 'A.M', 'G.M', sep='   ')

    for l in sorted(alg_ms, reverse=True):
        print(f'{l:#8.1f}', f'{alg_ms[l]:#3d}', f'{geo_ms[l]:#3d}', sep='   ')


print_alg_and_geo_multiplicities(A)
# Out:
# lambda     A.M   G.M
# 9.4+0.0j     1     1
# 0.3+1.0j     1     1
# 0.3-1.0j     1     1

# %% [markdown]
# ## Defective matrix

# %% [markdown]
# Any nontrivial Jordan block of 2×2 or larger (that is, not completely diagonal) is defective (degenerate).

# %%
J = np.array([[3, 1],
              [0, 3]])
print(J)
# Out:
# [[3 1]
#  [0 3]]

# %%
la, S = LA.eig(J)
print('la', la, '', 'S', S, sep='\n')
# Out:
# la
# [3.+0.j 3.+0.j]
#
# S
# [[ 1. -1.]
#  [ 0.  0.]]

# %%
assert_allclose(
    npLA.matrix_rank(S),
    1,
    atol=0.1
)

# %% [markdown]
# This Jordan matrix has only one eigenvector.

# %% [markdown]
# ## Diagonalizable matrix

# %% [markdown]
# $A=S \Lambda S^{-1}$

# %% [markdown]
# ### Normal

# %% [markdown]
# The square matrix A is _normal_ $\Longleftrightarrow$ $AA^H = A^HA$.

# %% [markdown]
# A _normal_ matrix is never defective. (It is always _diagonalizable_.)

# %% [markdown]
# Matrices are diagonalizable by _unitary_ matrices ($A=Q\Lambda Q^H$) if and only if they are _normal_.

# %% [markdown]
# #### Hermitian

# %% [markdown]
# A Hermitian matrix is always _normal_, so it is always _diagonalizable_ by _unitary_ matrices.

# %% [markdown]
# #### Unitary

# %% [markdown]
# A Unitary matrix is always _normal_.

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Matrix Power $A^{k}$

# %% [markdown]
# ## A diagonal matrix

# %%
D = np.diagflat(np.arange(1, 4))
print(D)
# Out:
# [[1 0 0]
#  [0 2 0]
#  [0 0 3]]

# %%
k = 2
print(matrix_power(D, k))
# Out:
# [[1 0 0]
#  [0 4 0]
#  [0 0 9]]

# %%
assert_allclose(
    matrix_power(D, k),
    D ** k
)

# %% [markdown]
# ## Any matrix

# %%
A = create_my_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %% [markdown]
# If A is diagonalizable, $A^k=SΛ^kS^{-1}$.

# %%
la, S = LA.eig(A)
print('la', la, '', 'S', S, sep='\n')
# Out:
# la
# [9.4+0.j 0.3+1.j 0.3-1.j]
#
# S
# [[ 0.3+0.j   0. -0.5j  0. +0.5j]
#  [ 0.9+0.j  -0.1+0.2j -0.1-0.2j]
#  [ 0.4+0.j   0.8+0.j   0.8-0.j ]]

# %%
k = 2

assert_allclose(
    matrix_power(A, k),
    S @ np.diagflat(la) ** k @ inv(S)
)

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Matrix Exponential $e^{At}$

# %% [markdown]
# ## A diagonal matrix

# %%
D = np.diagflat(np.arange(1, 4))
print(D)
# Out:
# [[1 0 0]
#  [0 2 0]
#  [0 0 3]]

# %%
print(expm(D))
# Out:
# [[ 2.7  0.   0. ]
#  [ 0.   7.4  0. ]
#  [ 0.   0.  20.1]]

# %%
t = 2

assert_allclose(
    expm(D * t),
    np.diagflat(np.e ** (np.diag(D) * t))
)

# %% [markdown]
# ## Any matrix

# %%
A = create_my_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %% [markdown]
# If A is diagonalizable, $e^{At}=Se^{Λt}S^{-1}$.

# %%
la, S = LA.eig(A)
print('la', la, '', 'S', S, sep='\n')
# Out:
# la
# [9.4+0.j 0.3+1.j 0.3-1.j]
#
# S
# [[ 0.3+0.j   0. -0.5j  0. +0.5j]
#  [ 0.9+0.j  -0.1+0.2j -0.1-0.2j]
#  [ 0.4+0.j   0.8+0.j   0.8-0.j ]]

# %%
t = 2

assert_allclose(
    expm(A * t),
    S @ expm(np.diagflat(la) * t) @ inv(S)
)

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Systems of difference equations

# %% [markdown]
# ## Discrete $u_{k}=A^{k}u_{0}$

# %% [markdown]
# ### e.g. Fibonacci

# %% [markdown]
# $f_{0}$ | $f_{1}$ | $f_{2}$ | $f_{3}$ | $f_{4}$ | $f_{5}$ | $f_{6}$ | $f_{7}$ | $...$ | $f_{100}$
# :- | :- | :- | :- | :- | :- | :- | :- | :- | :-
# 0 | 1 | 1 | 2 | 3 | 5 | 8 | 13 | $...$ | ?
#
#
# $f_{k+2} = f_{k+1} + f_{k} \ \rightarrow \ $ 2nd order differential equation (with 2nd derivative)
#
# "I want to get a two by two system first order, instead of a scalar system second order."
#
# 1st order system
# $
# \ \rightarrow \
# \begin{cases}
# f_{k+1} + f_{k} = f_{k+2} \\
# f_{k+1} + 0 = f_{k+1}
# \end{cases}
# \ \rightarrow \
# \begin{bmatrix}
# 1 & 1 \\
# 1 & 0
# \end{bmatrix}
# \begin{bmatrix}
# f_{k+1} \\
# f_{k}
# \end{bmatrix}
# =
# \begin{bmatrix}
# f_{k+2} \\
# f_{k+1}
# \end{bmatrix}
# \ \rightarrow \
# \begin{bmatrix}
# 1 & 1 \\
# 1 & 0
# \end{bmatrix}
# u_{k} = u_{k+1}
# $
#
# $
# \Rightarrow
# u_{k+1} = A u_{k}
# \ , \
# u_{0} =
# \begin{bmatrix}
# f_{1} \\
# f_{0}
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 \\
# 0
# \end{bmatrix}
# $
#
# $
# \Rightarrow
# u_{k} = A^{k} u_{0} = S \Lambda^{k} c \ , \ c = S^{-1} u_{0}
# $

# %%
A = np.array([[1, 1],
              [1, 0]])

u_0 = np.array([1, 0], dtype='float')


def u_by_recursion(k_):
    global A, u_0

    if k_ == 0:
        return u_0
    else:
        return A @ u_by_recursion(k_ - 1)


def u_by_diagonalization(k_):
    global A, u_0

    la_, S_ = npLA.eig(A)

    if k_ == 0:
        return u_0
    else:
        return S_ @ np.diagflat(la_ ** k_) @ inv(S_) @ u_0

# %%
def assert_diff_fib_are_close():
    n = 100
    assert_allclose(
        u_by_recursion(n),
        u_by_diagonalization(n)
    )


assert_diff_fib_are_close()

# %%
[round(u_by_diagonalization(n)[1]) for n in range(8)]
# Out:
# [0, 1, 1, 2, 3, 5, 8, 13]

# %%
print(f'{round(u_by_diagonalization(100)[1]):_}')
# Out:
# 354_224_848_179_263_045_632

# %% [markdown]
# ### Convergence

# %% [markdown]
# #### Stability

# %% [markdown]
# $\forall i: |\lambda_{i}|<1$

# %%
def matrix_power_leads_to_stability(la_):
    return (np.absolute(la_) < .9).all()


tolerance_factor = 1_000_000


def assert_norm_of_last_vector_is_by_far_smaller_than_first_one(v_0, v_last):
    assert_array_less(
        tolerance_factor * LA.norm(v_last),
        LA.norm(v_0)
    )

# %% [markdown]
# #### Steady State

# %% [markdown]
# $\exists i: |\lambda_{i}|=1, \forall j: |\lambda_{j}| \leq 1$

# %%
def matrix_power_leads_to_steady_state(la_):
    return (np.absolute(la_) > .9).any() and (np.absolute(la_) <= 1.1).all()


def assert_norm_of_last_vector_is_not_far_away_than_first_one(v_0, v_last):
    # It doesn't blow up.
    assert_array_less(
        LA.norm(v_last),
        tolerance_factor * LA.norm(v_0)
    )

    # It doesn't lead to stability.
    assert_array_less(
        LA.norm(v_0),
        tolerance_factor * LA.norm(v_last)
    )

# %% [markdown]
# #### Blow Up

# %% [markdown]
# $\exists i : |\lambda_{i}|>1$

# %%
def matrix_power_blows_up(la_):
    return (np.absolute(la_) > 1.1).any()


def assert_norm_of_last_vector_is_by_far_bigger_than_first_one(v_0, v_last):
    try:
        assert_(np.isinf(v_last).any())

    except AssertionError:
        assert_array_less(
            tolerance_factor * LA.norm(v_0),
            LA.norm(v_last)
        )

# %% [markdown]
# ### Analyze

# %%
A = create_my_array()

u_0 = np.ones(A.shape[0])

print('A', A, '', 'u_0', u_0[:, np.newaxis], sep='\n')
# Out:
# A
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]
#
# u_0
# [[1.]
#  [1.]
#  [1.]]

# %%
la = npLA.eigvals(A)
print('la', la, '', sep='\n')

print('la_abs', np.absolute(la), sep='\n')
# Out:
# la
# [9.4+0.j 0.3+1.j 0.3-1.j]
#
# la_abs
# [9.4 1.  1. ]

# %%
k = 100
A_to_the_k = matrix_power(A, k)
u_k = A_to_the_k @ u_0


class Styles:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARK_CYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'


convergence_message = {
    'stability': f'{Styles.GREEN}It is stable!{Styles.END}',
    'steady_state': f'{Styles.YELLOW}It approaches a steady state!{Styles.END}',
    'blow_up': f'{Styles.RED}It blows up!{Styles.END}'
}

convergence_result = ''

if matrix_power_leads_to_stability(la):
    assert_norm_of_last_vector_is_by_far_smaller_than_first_one(u_0, u_k)

    convergence_result = 'stability'

if matrix_power_leads_to_steady_state(la):
    assert_norm_of_last_vector_is_not_far_away_than_first_one(u_0, u_k)

    convergence_result = 'steady_state'

if matrix_power_blows_up(la):
    assert_norm_of_last_vector_is_by_far_bigger_than_first_one(u_0, u_k)

    convergence_result = 'blow_up'

print(convergence_message[convergence_result])

# print('', 'A_to_the_k', A_to_the_k, sep='\n')

print('', 'u_k', u_k[:, np.newaxis], sep='\n')
# Out:
# It blows up!
#
# u_k
# [[ 1.7e+18]
#  [-1.3e+19]
#  [-3.4e+18]]

# %% [markdown]
# #### Graph

# %%
def draw_2d_convergence_graph(x_, y_, color):
    fig, ax = plt.subplots(figsize=(7, 7))

    ax.plot(x_, y_, 'o-', lw=0.5, color=color)

    # Compute max_lim based on plotted data
    x_lim = abs(max(ax.get_xlim(), key=abs))
    y_lim = abs(max(ax.get_ylim(), key=abs))
    max_lim = max(x_lim, y_lim)

    # Position xyz axes to the center
    ax.set_xlim(xmin=-max_lim, xmax=max_lim)
    ax.set_ylim(ymin=-max_lim, ymax=max_lim)

    ax.grid(True, lw=.5)


from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d


class Arrow3D(FancyArrowPatch):
    """
    Ref: https://stackoverflow.com/a/22867877/4526384
    """

    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0, 0), (0, 0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0], ys[0]), (xs[1], ys[1]))
        FancyArrowPatch.draw(self, renderer)


def draw_xyz_axes_at_center(mpl_ax):
    # Compute max_lim based on plotted data
    x_lim = abs(max(mpl_ax.get_xlim(), key=abs))
    y_lim = abs(max(mpl_ax.get_ylim(), key=abs))
    z_lim = abs(max(mpl_ax.get_zlim(), key=abs))
    max_lim = max(x_lim, y_lim, z_lim)

    # Position xyz axes at the center
    mpl_ax.set_xlim(-max_lim, max_lim)
    mpl_ax.set_ylim(-max_lim, max_lim)
    mpl_ax.set_zlim(-max_lim, max_lim)

    # Draw xyz axes
    axes = ['x', 'y', 'z']
    for i, axis in enumerate(axes):
        start_end_pts = np.zeros((3, 2))
        start_end_pts[i] = [-max_lim, max_lim]

        # Draw axis
        xs, ys, zs = start_end_pts[0], start_end_pts[1], start_end_pts[2]

        a = Arrow3D(xs, ys, zs,
                    mutation_scale=20, arrowstyle='-|>', color='black')
        mpl_ax.add_artist(a)

        # Add label
        end_pt_with_padding = start_end_pts[:, 1] * 1.1

        mpl_ax.text(*end_pt_with_padding,
                    axis,
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='black')


def draw_3d_convergence_graph(x_, y_, z_, color):
    ax = plt.figure(figsize=(7, 7)).add_subplot(projection='3d')

    ax.plot(x_, y_, z_, '.-', lw=0.5, color=color)

    draw_xyz_axes_at_center(ax)

    ax.set_xlabel('x axis')
    ax.set_ylabel('y axis')
    ax.set_zlabel('z axis')

    plt.show()


def draw_convergence_graph(u_, color):
    if u_.shape[0] == 2:
        draw_2d_convergence_graph(u_[0, :], u_[1, :], color)

    elif u_.shape[0] == 3:
        draw_3d_convergence_graph(u_[0, :], u_[1, :], u_[2, :], color)


graph_color = {
    'stability': 'green',
    'steady_state': 'yellow',
    'blow_up': 'red'
}
u = [u_0]

for i in range(k):
    u.append(A @ u[-1])

# %matplotlib notebook

u = np.array(u).T

draw_convergence_graph(u, graph_color[convergence_result])

# %% [markdown]
# ## Continuous $u(t)=e^{At}u(0)$

# %% [markdown]
# ### e.g. A 2×2 system of diff eqs

# %% [markdown]
# $
# \begin{cases}
# \frac{du_{1}}{dt} = -u_{1}+2u_{2} \ , \ u_{1}(0)=1 \ , \ u_{1}(t)=? \\
# \\
# \frac{du_{2}}{dt} = \ \ \ u_{1}-2u_{2} \ , \ u_{2}(0)=0 \ , \ u_{2}(t)=?
# \end{cases}
# \\
# \
# \\
# A =
# \begin{bmatrix}
# -1 & 2 \\
# 1 & -2
# \end{bmatrix}
# \
# ,
# \
# u=
# \begin{bmatrix}
# u_{1} \\
# u_{2}
# \end{bmatrix}
# \
# \rightarrow
# \
# \frac{du}{dt} = Au
# \
# ,
# \
# u(0)=
# \begin{bmatrix}
# 1 \\
# 0
# \end{bmatrix}
# \\
# \
# \\
# u(t)=e^{At}u(0)=Se^{\Lambda t} c \ , \ c = S^{-1} u(0)
# $

# %%
A = np.array([[-1, 2],
              [1, -2]])

u_0 = np.array([1, 0], dtype='float')


def u(t_):
    return expm(A * t_) @ u_0

# %% [markdown]
# $
# u_{1}(100)=?
# \\
# u_{2}(100)=?
# $

# %%
print(u(100).reshape(2, 1))
# Out:
# [[0.7]
#  [0.3]]

# %% [markdown]
# ### e.g. A 2nd order diff eq

# %% [markdown]
# $
# y^{''}+by^{'}+ky=0
# \
# \Rightarrow
# \
# \begin{cases}
# y^{''}=-by^{'}-ky
# \\
# y^{'}= \ \ \ \ \ y^{'}+0
# \end{cases}
# \
# \Rightarrow
# \
# \begin{bmatrix}
# y^{''}
# \\
# y^{'}
# \end{bmatrix}
# =
# \begin{bmatrix}
# -b & -k \\
# 1 & 0
# \end{bmatrix}
# \begin{bmatrix}
# y^{'}
# \\
# y
# \end{bmatrix}
# \
# \Rightarrow
# \
# \frac{du}{dt}=u^{'}=Au
# \
# \Rightarrow
# \
# u(t)=e^{At}u(0)
# $

# %% [markdown]
# ### Convergence

# %% [markdown]
# #### Stability

# %% [markdown]
# $\forall i: Re\lambda_{i}<0$

# %%
def matrix_exponential_leads_to_stability(la_):
    return (la_.real <= -0.1).all()

# %% [markdown]
# #### Steady State

# %% [markdown]
# $\exists i: Re\lambda_{i}=0, \forall j: Re\lambda_{j} \leq 0$

# %%
def matrix_exponential_leads_to_steady_state(la_):
    return (la_.real < 0.1).all() and (-0.1 < la_.real).any()

# %% [markdown]
# #### Blow Up

# %% [markdown]
# $\exists i: Re\lambda_{i}>0$

# %%
def matrix_exponential_blows_up(la_):
    return (la_.real >= 0.1).any()

# %% [markdown]
# ### Analyze

# %%
A = create_my_array()

u_0 = np.ones(A.shape[0])

print('A', A, '', 'u_0', u_0[:, np.newaxis], sep='\n')
# Out:
# A
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]
#
# u_0
# [[1.]
#  [1.]
#  [1.]]

# %%
la = npLA.eigvals(A)
print('la', la, sep='\n')
# Out:
# la
# [9.4+0.j 0.3+1.j 0.3-1.j]

# %%
t = 100
e_to_the_At = expm(A * t)
u_t = e_to_the_At @ u_0

convergence_result = ''

if matrix_exponential_leads_to_stability(la):
    assert_norm_of_last_vector_is_by_far_smaller_than_first_one(u_0, u_t)

    convergence_result = 'stability'

if matrix_exponential_leads_to_steady_state(la):
    assert_norm_of_last_vector_is_not_far_away_than_first_one(u_0, u_t)

    convergence_result = 'steady_state'

if matrix_exponential_blows_up(la):
    assert_norm_of_last_vector_is_by_far_bigger_than_first_one(u_0, u_t)

    convergence_result = 'blow_up'

print(convergence_message[convergence_result])

# print('', 'e_to_the_At', e_to_the_At, sep='\n')

print('', 'u_t', u_t[:, np.newaxis], sep='\n')
# Out:
# It blows up!
#
# u_t
# [[inf]
#  [inf]
#  [inf]]

# %% [markdown]
# #### Graph

# %%
u = [u_0]

dt = .1
for i in range(int(t / dt)):
    du = A @ u[-1] * dt
    u.append(u[-1] + du)

u = np.array(u).T
draw_convergence_graph(u, graph_color[convergence_result])

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Markov matrix

# %%
A = create_a_Markov_matrix()
print(A)
# Out:
# [[0.1 0.  0.3]
#  [0.2 1.  0.3]
#  [0.7 0.  0.4]]

# %%
la, S = npLA.eig(A)
print('la', la, '', 'S', S, sep='\n')
# Out:
# la
# [-0.2  0.7  1. ]
#
# S
# [[ 0.7 -0.3 -0. ]
#  [ 0.1  0.8 -1. ]
#  [-0.7 -0.5 -0. ]]

# %% [markdown]
# ## All entries are 0 or positive

# %%
def assert_all_entries_are_0_or_positive(M):
    assert_(
        (M >= 0).all()
    )


assert_all_entries_are_0_or_positive(A)

# %% [markdown]
# ## All columns add to 1

# %%
def assert_all_columns_add_to_1(M):
    assert_allclose(
        np.sum(M, axis=0).all(),
        1
    )


assert_all_columns_add_to_1(A)

# %% [markdown]
# ## $\exists i: \lambda_{i} = 1$

# %%
def assert_at_least_an_eigenvalue_is_close_to_1(la_):
    assert_(
        np.isclose(la_, 1).any()
    )


assert_at_least_an_eigenvalue_is_close_to_1(la)

# %% [markdown]
# ## $\forall j \ne i , |\lambda_{j}| \leq 1$

# %%
def assert_all_eigenvalues_are_less_than_or_close_to_1(la_):
    assert_array_less(
        np.absolute(la_),
        np.full_like(la_, 1.1),
    )


assert_all_eigenvalues_are_less_than_or_close_to_1(la)

# %% [markdown]
# ## It converges to a positive steady state

# %%
k = 100
A_to_the_k = matrix_power(A, k)

u_0 = np.ones(A.shape[0])
u_k = A_to_the_k @ u_0

la = npLA.eigvals(A_to_the_k)

assert_array_less(np.zeros_like(u_k), u_k)
assert_norm_of_last_vector_is_not_far_away_than_first_one(u_0, u_k)

# %% [markdown]
# ## $A^{k}$ is still Markov

# %%
assert_all_entries_are_0_or_positive(A_to_the_k)
assert_all_columns_add_to_1(A_to_the_k)
assert_at_least_an_eigenvalue_is_close_to_1(la)
assert_all_eigenvalues_are_less_than_or_close_to_1(la)

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Expansion with a basis

# %%
v = np.array([1, 2, 3])
print('Vector', v, sep='\n')
# Out:
# Vector
# [1 2 3]

# %% [markdown]
# ## With A

# %%
A = create_a_square_invertible_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %%
x = inv(A.T @ A) @ A.T @ v
print(x)
# Out:
# [-1.   0.5  1. ]

# %%
assert_allclose(
    A @ x,
    v
)

# %% [markdown]
# ## With Q (orthonormal basis)

# %%
Q = LA.orth(A)
print(Q)
# Out:
# [[-0.2  0.1  1. ]
#  [-0.9  0.4 -0.3]
#  [-0.4 -0.9 -0. ]]

# %%
x = Q.T @ v
print('Cofactors on Q', x, sep='\n')
# Out:
# Cofactors on Q
# [-3.2 -1.9  0.4]

# %%
assert_allclose(
    Q @ x,
    v
)

# %% [markdown]
# ## With S (eigenvectors)

# %%
la, S = npLA.eig(A)
print('la', la, '', 'S', S, sep='\n')
# Out:
# la
# [9.4+0.j 0.3+1.j 0.3-1.j]
#
# S
# [[ 0.3+0.j   0. -0.5j  0. +0.5j]
#  [ 0.9+0.j  -0.1+0.2j -0.1-0.2j]
#  [ 0.4+0.j   0.8+0.j   0.8-0.j ]]

# %%
x = inv(S.T @ S) @ S.T @ v
print(x)
# Out:
# [2.8-0.j  1.2+0.2j 1.2-0.2j]

# %%
assert_allclose(
    S @ (x * la),
    A @ v
)

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Complex Vectors and Matrices

# %%
z = np.array([1, 1j])
print(z)
# Out:
# [1.+0.j 0.+1.j]

# %%
length_squared = z.conj().T @ z

assert_allclose(
    length_squared,
    LA.norm(z) ** 2
)

# %% [markdown]
# ## Hermitian matrix

# %%
A = create_a_Hermitian_array()
print(A)
# Out:
# [[ 1.+0.j  0.+2.j  1.+1.j]
#  [-0.-2.j  8.+0.j  4.-3.j]
#  [ 1.-1.j  4.+3.j -3.+0.j]]

# %%
assert_allclose(
    A.conj().T,
    A
)

# %% [markdown]
# ## Unitary matrix

# %%
Q = create_a_unitary_array()
print(Q)
# Out:
# [[0.5+0.5j 0.5-0.5j]
#  [0.5-0.5j 0.5+0.5j]]

# %%
assert_allclose(
    inv(Q),
    Q.conj().T
)

# %% [markdown]
# [&#x21e7;](#Contents)

# %% [markdown]
# # Positive Definite Matrices

# %%
A = create_my_array()
print(A)
# Out:
# [[1 2 1]
#  [3 8 1]
#  [0 4 1]]

# %%
la = LA.eigvals(A)
(la > 0).all()
# Out:
# True

# %%
U = LA.lu(A)[2]
pivots = np.diag(U)
(pivots > 0).all()
# Out:
# True

# %%
sub_dets_of_A = np.array([det(A[:i, :i]) for i in range(1, A.shape[0] + 1)])
(sub_dets_of_A > 0).all()
# Out:
# True

# %% [markdown]
# [&#x21e7;](#Contents)
